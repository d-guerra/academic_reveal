# %% [markdown]
# <a href="https://colab.research.google.com/github/d-guerra/academic_reveal/blob/master/C%C3%B3pia_de_EP3_Pyperplan.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# NOME: <font color='red'> \<escreva seu nome aqui\>
#
# NUSP: <font color='red'> \<escreva seu nome número USP aqui\>
#
#
# ---

# %% [markdown]
# # *EP 3 - Pyperplan*
#
# Neste exercício programa vamos
# usar o planejador Pyplerplan (disponível em https://github.com/aibasel/pyperplan). O Pyperplan é um planejador PDDL/STRIPS escrito em Python, projetado para ser usado como uma
# ferramenta de ensino ou de prototipagem.
#
# Você deve criar uma cópia deste arquivo, executar as células contendo exemplos de comandos para utilizar o Pyperplan, e então preencher e executar as células na seção intitulada "Experimentos a serem Realizados".
#
# Note que esse EP não requer programação.

# %% [markdown]
# # Tarefa 1 - Instalação do Pyperplan
#
# Para obter e instalar o Pyperplan, você pode seguir as instruções disponíveis no arquivo "README" do respositório do planejador (https://github.com/aibasel/pyperplan), ou simplesmente executar a célula a seguir.
#
# Se optar por executar a célula, basta baixar este notebook em um diretório **vazio** e rodá-lo (a execução do script abaixo remove todos os arquivos do diretório em que o notebook estiver), ou executá-lo diretamente no Google Colab.

# %%
# %%bash
#
# # remove os arquivos existentes do Colab
#  rm -rf ./*
#
# # faz o download do repositório na pasta atual
# curl --silent -L https://github.com/aibasel/pyperplan/tarball/main | tar -xz
#
# files=(*)
# dir_name="${files[0]}"
#
# mv $dir_name/* .
# rm -rf $dir_name
#
# # instala o repositório como um pacote do PIP
# pip --quiet install --editable .

# %% [markdown]
# # Tarefa 2 - Experimentos
#
#
# ## Como rodar os experimentos
#
# Com o código localizado na sua máquina (ou rodando este notebook diretamente no Colab), é possível executar o Pyperplan passando um arquivo de descrição de domínio em STRIPS e outro de descrição da instância de um problema do domínio. Por exemplo:
#
# ```pyperplan <DOMÍNIO> <PROBLEMA>```
#
# Os domínios disponíveis estão localizados na pasta "benchmarks" do projeto (ver https://github.com/aibasel/pyperplan/tree/main/benchmarks).
#
#
# Por padrão, o pyperplan executa uma busca em largura sem heurística. No entanto, o pyperplan possui algoritmos de busca com heurística. Na célula abaixo temos um exemplo de execução do planejador para o domínio TTP (no arquivo benchmarks/tpp/domain.pddl) com a instância 1 (arquivo benchmarks/tpp/task01.pddl) usando a heurística FF e o algoritmo de busca "best-first":

# %%
# %%bash
# pyperplan --heuristic hff --search bfs benchmarks/tpp/domain.pddl benchmarks/tpp/task01.pddl
# Out:
# 2026-06-20 14:11:47,822 INFO     Python version: 3.12.13 (main, Mar  4 2026, 09:23:07) [GCC 11.4.0]
# 2026-06-20 14:11:47,822 INFO     using search: breadth_first_search
# 2026-06-20 14:11:47,823 INFO     using heuristic: None
# 2026-06-20 14:11:47,823 INFO     Parsing Domain /content/benchmarks/tpp/domain.pddl
# 2026-06-20 14:11:47,825 INFO     Parsing Problem /content/benchmarks/tpp/task01.pddl
# 2026-06-20 14:11:47,826 INFO     7 Predicates parsed
# 2026-06-20 14:11:47,826 INFO     4 Actions parsed
# 2026-06-20 14:11:47,826 INFO     6 Objects parsed
# 2026-06-20 14:11:47,826 INFO     0 Constants parsed
# 2026-06-20 14:11:47,826 INFO     Grounding start: tpp
# 2026-06-20 14:11:47,826 INFO     Grounding end: tpp
# 2026-06-20 14:11:47,826 INFO     10 Variables created
# 2026-06-20 14:11:47,827 INFO     5 Operators created
# 2026-06-20 14:11:47,827 INFO     Search start: tpp
# 2026-06-20 14:11:47,827 INFO     Goal reached. Start extraction of solution.
# ...

# %% [markdown]
# Caso o comando acima tenha sido executado com sucesso, você deverá ter observado algumas estatíscas do problema. Essas estatísticas incluem o comprimento do plano (Plan length), o tempo de busca (Search time) e outros dados relevantes. Logo abaixo, é fornecido um exemplo ilustrativo da saída que o planejador pode gerar:
#
#
# ```
# ...
# INFO     7 Predicates parsed
# INFO     4 Actions parsed
# INFO     6 Objects parsed
# INFO     0 Constants parsed
# INFO     Grounding start: tpp
# INFO     Relevance analysis removed 1 facts
# INFO     Grounding end: tpp
# INFO     10 Variables created
# INFO     5 Operators created
# INFO     Search start: tpp
# INFO     Goal reached. Start extraction of solution.
# INFO     7 Nodes expanded
# INFO     Search end: tpp
# INFO     Search time: 0.00016
# INFO     Plan length: 5
# INFO     validate could not be found on the PATH so the plan can not be validated.
#
# ```
#
# Após a execução do planejador, um arquivo com a extensão **.soln** é gerado na mesma pasta do arquivo da instância do problema. Esse arquivo contém a solução encontrada pelo planejador, ou seja, o plano para resolver o problema em questão.

# %%
# %%bash
# echo "Solução do problema 'task01' para o domínio 'tpp':"
# echo ""
# cat benchmarks/tpp/task01.pddl.soln
# Out:
# Solução do problema 'task01' para o domínio 'tpp':
#
# (drive truck1 depot1 market1)
# (buy truck1 goods1 market1 level0 level1 level0 level1)
# (load goods1 truck1 market1 level0 level1 level0 level1)
# (drive truck1 market1 depot1)
# (unload goods1 truck1 depot1 level0 level1 level0 level1)

# %% [markdown]
# Para obter informações mais detalhadas sobre as heurísticas e algoritmos de busca disponibilizados pelo Pyperplan, é possível consultar a função de ajuda do programa. Para fazer isso, basta executar a célula abaixo:

# %%
# %%bash
# pyperplan --help
# Out:
# usage: pyperplan [-h] [-l {debug,info,warning,error}]
#                  [-H {landmark,hadd,hff,hmax,hsa,blind,lmcut}]
#                  [-s {astar,wastar,gbfs,bfs,ehs,ids,sat}]
#                  [--successor-generator {naive,tree}]
#                  [domain] problem
#
# positional arguments:
#   domain
#   problem
#
# options:
#   -h, --help            show this help message and exit
#   -l {debug,info,warning,error}, --loglevel {debug,info,warning,error}
#   -H {landmark,hadd,hff,hmax,hsa,blind,lmcut}, --heuristic {landmark,hadd,hff,hmax,hsa,blind,lmcut}
#                         Select a heuristic (default: hff)
#   -s {astar,wastar,gbfs,bfs,ehs,ids,sat}, --search {astar,wastar,gbfs,bfs,ehs,ids,sat}
#                         Select a search algorithm from astar, weighted astar,
#                         greedy best first, breadth first, enforced
#                         hillclimbing, iterative deepening, sat solve (default:
#                         bfs)
# ...

# %% [markdown]
# ## Experimentos a serem realizados
#
# Execute o Pyperplan para os seguintes problemas dos domínios `rovers`, `logistics` e `blocks`:
# * Rovers: `task01`, `task02`, `task03`;
# * Logistics: `task01`, `task03`, `task05`;
# * Blocksworld: `task10`, `task15`, `task20`.
#
# Para cada instância, você deve executar o Pyperplan três vezes: uma vez utilizando a heurística **hadd**, outra utilizando a heurística **hmax** e outra  **hff**. Em todos os casos você deve utilizar o algoritmo de busca **astar**. Por exemplo, para o domínio Blocksworld e o problema task01.pddl, a execução do Pyperplan deve seguir o seguinte formato:
#
#
# ```
# pyperplan --heuristic hadd --search astar benchmarks/blocks/domain.pddl benchmarks/blocks/task01.pddl
# ```
# ```
# pyperplan --heuristic hmax --search astar benchmarks/blocks/domain.pddl benchmarks/blocks/task01.pddl
# ```
# ```
# pyperplan --heuristic hff --search astar benchmarks/blocks/domain.pddl benchmarks/blocks/task01.pddl
# ```
#
# Os experimentos devem ser executados neste notebook (nas células a seguir). O relatório deve ser entregues em um documento PDF separado.
#
# ## Relatório
#
# O relatório deve conter uma ou mais tabelas com os resultados das execuções e um texto de discussão que referencie os dados coletados. Por exemplo, é interessante comparar o tempo de execução e o tamanho do plano devolvido na solução de diferentes instâncias com o emprego de diferentes heurísticas. Além disso, para guiar o discussão, o relatório deve incluir respostas às perguntas descritas abaixo.
#
#
# ### Tabelas
#
# Faça uma tabela com os seguintes resultados estatísticos devolvidos pelo próprio Pyperplan, para cada heurística em cada problema:
#
# * Initial h value
# * Nodes expanded
# * Search time
# * Plan length
#
# Além disso, para enriquecer a análise dos resultados, inclua os dados relativos às características dos domínios e dos problemas:
#
# * Predicates parsed
# * Actions parsed
# * Objects parsed
# * Constants parsed
# * Variables created
# * Operators created
#
# ### Perguntas
#
# 1. Em termos do tamanho do plano devolvido pelo planejador, podemos dizer que o Pyperplan sempre devolve o plano ótimo, independentemente da heurística utilizada? Justifique sua resposta.
# 2. Considerando o tempo de execução para encontrar um plano solução, analise o desempenho das 3 heurísticas empregadas. Podemos atribuir o melhor desempenho em termos de número de nós expandidos na busca? E pelo tempo gasto no cálculo da heurística?
# 3. Por que a busca A* utilizando diferentes heurísticas expande um número diferente de nós?
# 4. Estude os arquivos **pddl** dos domínios e problemas testados. Como as características dos domínios (como o número de predicados ou ações) impactam na busca? Como explicar que 2 problemas do mesmo domínio, com o mesmo número de predicados, objetos e constantes podem consumir tempos diferentes?

# %% [markdown]
# ### Domínio Rovers
#
# <font color='red'> Insira os comandos de execução do Pyperplan para o domínio `rovers` nas células a seguir (cada problema em uma célula). </font>

# %% [markdown]
# Pyperplan com A* e hadd:

# %%
# %%bash
# pyperplan --heuristic hadd --search astar benchmarks/blocks/domain.pddl benchmarks/blocks/task01.pddl
# Out:
# 2026-06-20 14:24:53,558 INFO     Python version: 3.12.13 (main, Mar  4 2026, 09:23:07) [GCC 11.4.0]
# 2026-06-20 14:24:53,558 INFO     using search: astar_search
# 2026-06-20 14:24:53,559 INFO     using heuristic: hAddHeuristic
# 2026-06-20 14:24:53,559 INFO     Parsing Domain /content/benchmarks/blocks/domain.pddl
# 2026-06-20 14:24:53,560 INFO     Parsing Problem /content/benchmarks/blocks/task01.pddl
# 2026-06-20 14:24:53,560 INFO     5 Predicates parsed
# 2026-06-20 14:24:53,560 INFO     4 Actions parsed
# 2026-06-20 14:24:53,560 INFO     4 Objects parsed
# 2026-06-20 14:24:53,560 INFO     0 Constants parsed
# 2026-06-20 14:24:53,560 INFO     Grounding start: blocks-4-0
# 2026-06-20 14:24:53,561 INFO     Grounding end: blocks-4-0
# 2026-06-20 14:24:53,561 INFO     29 Variables created
# 2026-06-20 14:24:53,561 INFO     40 Operators created
# 2026-06-20 14:24:53,561 INFO     Search start: blocks-4-0
# 2026-06-20 14:24:53,563 INFO     Initial h value: 6.000000
# ...

# %%
# %%bash
# pyperplan --heuristic hadd --search astar benchmarks/blocks/domain.pddl benchmarks/blocks/task02.pddl
# Out:
# 2026-06-20 14:25:20,529 INFO     Python version: 3.12.13 (main, Mar  4 2026, 09:23:07) [GCC 11.4.0]
# 2026-06-20 14:25:20,529 INFO     using search: astar_search
# 2026-06-20 14:25:20,529 INFO     using heuristic: hAddHeuristic
# 2026-06-20 14:25:20,529 INFO     Parsing Domain /content/benchmarks/blocks/domain.pddl
# 2026-06-20 14:25:20,530 INFO     Parsing Problem /content/benchmarks/blocks/task02.pddl
# 2026-06-20 14:25:20,531 INFO     5 Predicates parsed
# 2026-06-20 14:25:20,531 INFO     4 Actions parsed
# 2026-06-20 14:25:20,531 INFO     4 Objects parsed
# 2026-06-20 14:25:20,531 INFO     0 Constants parsed
# 2026-06-20 14:25:20,531 INFO     Grounding start: blocks-4-1
# 2026-06-20 14:25:20,532 INFO     Grounding end: blocks-4-1
# 2026-06-20 14:25:20,532 INFO     29 Variables created
# 2026-06-20 14:25:20,532 INFO     40 Operators created
# 2026-06-20 14:25:20,532 INFO     Search start: blocks-4-1
# 2026-06-20 14:25:20,532 INFO     Initial h value: 10.000000
# ...

# %%
# %%bash
# pyperplan --heuristic hadd --search astar benchmarks/blocks/domain.pddl benchmarks/blocks/task03.pddl
# Out:
# 2026-06-20 14:25:23,139 INFO     Python version: 3.12.13 (main, Mar  4 2026, 09:23:07) [GCC 11.4.0]
# 2026-06-20 14:25:23,139 INFO     using search: astar_search
# 2026-06-20 14:25:23,139 INFO     using heuristic: hAddHeuristic
# 2026-06-20 14:25:23,139 INFO     Parsing Domain /content/benchmarks/blocks/domain.pddl
# 2026-06-20 14:25:23,140 INFO     Parsing Problem /content/benchmarks/blocks/task03.pddl
# 2026-06-20 14:25:23,141 INFO     5 Predicates parsed
# 2026-06-20 14:25:23,141 INFO     4 Actions parsed
# 2026-06-20 14:25:23,141 INFO     4 Objects parsed
# 2026-06-20 14:25:23,141 INFO     0 Constants parsed
# 2026-06-20 14:25:23,141 INFO     Grounding start: blocks-4-2
# 2026-06-20 14:25:23,142 INFO     Grounding end: blocks-4-2
# 2026-06-20 14:25:23,142 INFO     29 Variables created
# 2026-06-20 14:25:23,142 INFO     40 Operators created
# 2026-06-20 14:25:23,143 INFO     Search start: blocks-4-2
# 2026-06-20 14:25:23,143 INFO     Initial h value: 8.000000
# ...

# %% [markdown]
# Pyperplan com A* e hmax:

# %%
# %%bash
# pyperplan --heuristic hmax --search astar benchmarks/blocks/domain.pddl benchmarks/blocks/task01.pddl
# Out:
# 2026-06-20 14:29:09,125 INFO     Python version: 3.12.13 (main, Mar  4 2026, 09:23:07) [GCC 11.4.0]
# 2026-06-20 14:29:09,125 INFO     using search: astar_search
# 2026-06-20 14:29:09,126 INFO     using heuristic: hMaxHeuristic
# 2026-06-20 14:29:09,126 INFO     Parsing Domain /content/benchmarks/blocks/domain.pddl
# 2026-06-20 14:29:09,128 INFO     Parsing Problem /content/benchmarks/blocks/task01.pddl
# 2026-06-20 14:29:09,128 INFO     5 Predicates parsed
# 2026-06-20 14:29:09,129 INFO     4 Actions parsed
# 2026-06-20 14:29:09,129 INFO     4 Objects parsed
# 2026-06-20 14:29:09,129 INFO     0 Constants parsed
# 2026-06-20 14:29:09,129 INFO     Grounding start: blocks-4-0
# 2026-06-20 14:29:09,130 INFO     Grounding end: blocks-4-0
# 2026-06-20 14:29:09,130 INFO     29 Variables created
# 2026-06-20 14:29:09,130 INFO     40 Operators created
# 2026-06-20 14:29:09,131 INFO     Search start: blocks-4-0
# 2026-06-20 14:29:09,133 INFO     Initial h value: 2.000000
# ...

# %%
# %%bash
# pyperplan --heuristic hmax --search astar benchmarks/blocks/domain.pddl benchmarks/blocks/task02.pddl
# Out:
# 2026-06-20 14:29:11,611 INFO     Python version: 3.12.13 (main, Mar  4 2026, 09:23:07) [GCC 11.4.0]
# 2026-06-20 14:29:11,611 INFO     using search: astar_search
# 2026-06-20 14:29:11,611 INFO     using heuristic: hMaxHeuristic
# 2026-06-20 14:29:11,611 INFO     Parsing Domain /content/benchmarks/blocks/domain.pddl
# 2026-06-20 14:29:11,612 INFO     Parsing Problem /content/benchmarks/blocks/task02.pddl
# 2026-06-20 14:29:11,613 INFO     5 Predicates parsed
# 2026-06-20 14:29:11,613 INFO     4 Actions parsed
# 2026-06-20 14:29:11,613 INFO     4 Objects parsed
# 2026-06-20 14:29:11,613 INFO     0 Constants parsed
# 2026-06-20 14:29:11,613 INFO     Grounding start: blocks-4-1
# 2026-06-20 14:29:11,614 INFO     Grounding end: blocks-4-1
# 2026-06-20 14:29:11,614 INFO     29 Variables created
# 2026-06-20 14:29:11,614 INFO     40 Operators created
# 2026-06-20 14:29:11,614 INFO     Search start: blocks-4-1
# 2026-06-20 14:29:11,614 INFO     Initial h value: 5.000000
# ...

# %%
# %%bash
# pyperplan --heuristic hmax --search astar benchmarks/blocks/domain.pddl benchmarks/blocks/task03.pddl
# Out:
# 2026-06-20 14:29:13,529 INFO     Python version: 3.12.13 (main, Mar  4 2026, 09:23:07) [GCC 11.4.0]
# 2026-06-20 14:29:13,529 INFO     using search: astar_search
# 2026-06-20 14:29:13,529 INFO     using heuristic: hMaxHeuristic
# 2026-06-20 14:29:13,529 INFO     Parsing Domain /content/benchmarks/blocks/domain.pddl
# 2026-06-20 14:29:13,531 INFO     Parsing Problem /content/benchmarks/blocks/task03.pddl
# 2026-06-20 14:29:13,531 INFO     5 Predicates parsed
# 2026-06-20 14:29:13,531 INFO     4 Actions parsed
# 2026-06-20 14:29:13,531 INFO     4 Objects parsed
# 2026-06-20 14:29:13,531 INFO     0 Constants parsed
# 2026-06-20 14:29:13,531 INFO     Grounding start: blocks-4-2
# 2026-06-20 14:29:13,532 INFO     Grounding end: blocks-4-2
# 2026-06-20 14:29:13,532 INFO     29 Variables created
# 2026-06-20 14:29:13,532 INFO     40 Operators created
# 2026-06-20 14:29:13,533 INFO     Search start: blocks-4-2
# 2026-06-20 14:29:13,533 INFO     Initial h value: 3.000000
# ...

# %% [markdown]
# Pyperplan com A* e hff:

# %%
# %%bash
# pyperplan --heuristic hff --search astar benchmarks/blocks/domain.pddl benchmarks/blocks/task01.pddl
# Out:
# 2026-06-20 14:29:24,645 INFO     Python version: 3.12.13 (main, Mar  4 2026, 09:23:07) [GCC 11.4.0]
# 2026-06-20 14:29:24,646 INFO     using search: astar_search
# 2026-06-20 14:29:24,646 INFO     using heuristic: hFFHeuristic
# 2026-06-20 14:29:24,646 INFO     Parsing Domain /content/benchmarks/blocks/domain.pddl
# 2026-06-20 14:29:24,647 INFO     Parsing Problem /content/benchmarks/blocks/task01.pddl
# 2026-06-20 14:29:24,647 INFO     5 Predicates parsed
# 2026-06-20 14:29:24,647 INFO     4 Actions parsed
# 2026-06-20 14:29:24,647 INFO     4 Objects parsed
# 2026-06-20 14:29:24,647 INFO     0 Constants parsed
# 2026-06-20 14:29:24,648 INFO     Grounding start: blocks-4-0
# 2026-06-20 14:29:24,648 INFO     Grounding end: blocks-4-0
# 2026-06-20 14:29:24,648 INFO     29 Variables created
# 2026-06-20 14:29:24,648 INFO     40 Operators created
# 2026-06-20 14:29:24,649 INFO     Search start: blocks-4-0
# 2026-06-20 14:29:24,650 INFO     Initial h value: 6.000000
# ...

# %%
# %%bash
# pyperplan --heuristic hff --search astar benchmarks/blocks/domain.pddl benchmarks/blocks/task02.pddl
# Out:
# 2026-06-20 14:29:26,546 INFO     Python version: 3.12.13 (main, Mar  4 2026, 09:23:07) [GCC 11.4.0]
# 2026-06-20 14:29:26,546 INFO     using search: astar_search
# 2026-06-20 14:29:26,546 INFO     using heuristic: hFFHeuristic
# 2026-06-20 14:29:26,546 INFO     Parsing Domain /content/benchmarks/blocks/domain.pddl
# 2026-06-20 14:29:26,547 INFO     Parsing Problem /content/benchmarks/blocks/task02.pddl
# 2026-06-20 14:29:26,548 INFO     5 Predicates parsed
# 2026-06-20 14:29:26,548 INFO     4 Actions parsed
# 2026-06-20 14:29:26,548 INFO     4 Objects parsed
# 2026-06-20 14:29:26,548 INFO     0 Constants parsed
# 2026-06-20 14:29:26,548 INFO     Grounding start: blocks-4-1
# 2026-06-20 14:29:26,548 INFO     Grounding end: blocks-4-1
# 2026-06-20 14:29:26,549 INFO     29 Variables created
# 2026-06-20 14:29:26,549 INFO     40 Operators created
# 2026-06-20 14:29:26,549 INFO     Search start: blocks-4-1
# 2026-06-20 14:29:26,549 INFO     Initial h value: 6.000000
# ...

# %%
# %%bash
# pyperplan --heuristic hff --search astar benchmarks/blocks/domain.pddl benchmarks/blocks/task03.pddl
# Out:
# 2026-06-20 14:29:28,630 INFO     Python version: 3.12.13 (main, Mar  4 2026, 09:23:07) [GCC 11.4.0]
# 2026-06-20 14:29:28,630 INFO     using search: astar_search
# 2026-06-20 14:29:28,630 INFO     using heuristic: hFFHeuristic
# 2026-06-20 14:29:28,630 INFO     Parsing Domain /content/benchmarks/blocks/domain.pddl
# 2026-06-20 14:29:28,631 INFO     Parsing Problem /content/benchmarks/blocks/task03.pddl
# 2026-06-20 14:29:28,631 INFO     5 Predicates parsed
# 2026-06-20 14:29:28,632 INFO     4 Actions parsed
# 2026-06-20 14:29:28,632 INFO     4 Objects parsed
# 2026-06-20 14:29:28,632 INFO     0 Constants parsed
# 2026-06-20 14:29:28,632 INFO     Grounding start: blocks-4-2
# 2026-06-20 14:29:28,632 INFO     Grounding end: blocks-4-2
# 2026-06-20 14:29:28,632 INFO     29 Variables created
# 2026-06-20 14:29:28,632 INFO     40 Operators created
# 2026-06-20 14:29:28,633 INFO     Search start: blocks-4-2
# 2026-06-20 14:29:28,633 INFO     Initial h value: 6.000000
# ...

# %% [markdown]
# ### Domínio Logistics
#
# <font color='red'> Insira os comandos de execução do Pyperplan para o domínio `logistics` nas células a seguir (cada problema em uma célula). </font>

# %% [markdown]
# Pyperplan com A* e hadd:

# %%
# %%bash
# pyperplan --heuristic hadd --search astar benchmarks/logistics/domain.pddl benchmarks/logistics/task01.pddl
# Out:
# 2026-06-20 14:34:52,916 INFO     Python version: 3.12.13 (main, Mar  4 2026, 09:23:07) [GCC 11.4.0]
# 2026-06-20 14:34:52,917 INFO     using search: astar_search
# 2026-06-20 14:34:52,917 INFO     using heuristic: hAddHeuristic
# 2026-06-20 14:34:52,917 INFO     Parsing Domain /content/benchmarks/logistics/domain.pddl
# 2026-06-20 14:34:52,919 INFO     Parsing Problem /content/benchmarks/logistics/task01.pddl
# 2026-06-20 14:34:52,919 INFO     3 Predicates parsed
# 2026-06-20 14:34:52,919 INFO     6 Actions parsed
# 2026-06-20 14:34:52,919 INFO     15 Objects parsed
# 2026-06-20 14:34:52,919 INFO     0 Constants parsed
# 2026-06-20 14:34:52,919 INFO     Grounding start: logistics-4-0
# 2026-06-20 14:34:52,922 INFO     Grounding end: logistics-4-0
# 2026-06-20 14:34:52,922 INFO     54 Variables created
# 2026-06-20 14:34:52,922 INFO     106 Operators created
# 2026-06-20 14:34:52,924 INFO     Search start: logistics-4-0
# 2026-06-20 14:34:52,924 INFO     Initial h value: 24.000000
# ...

# %%
# %%bash
# pyperplan --heuristic hadd --search astar benchmarks/logistics/domain.pddl benchmarks/logistics/task03.pddl
# Out:
# 2026-06-20 14:34:55,107 INFO     Python version: 3.12.13 (main, Mar  4 2026, 09:23:07) [GCC 11.4.0]
# 2026-06-20 14:34:55,107 INFO     using search: astar_search
# 2026-06-20 14:34:55,107 INFO     using heuristic: hAddHeuristic
# 2026-06-20 14:34:55,107 INFO     Parsing Domain /content/benchmarks/logistics/domain.pddl
# 2026-06-20 14:34:55,109 INFO     Parsing Problem /content/benchmarks/logistics/task03.pddl
# 2026-06-20 14:34:55,110 INFO     3 Predicates parsed
# 2026-06-20 14:34:55,110 INFO     6 Actions parsed
# 2026-06-20 14:34:55,110 INFO     15 Objects parsed
# 2026-06-20 14:34:55,110 INFO     0 Constants parsed
# 2026-06-20 14:34:55,110 INFO     Grounding start: logistics-4-2
# 2026-06-20 14:34:55,115 INFO     Grounding end: logistics-4-2
# 2026-06-20 14:34:55,115 INFO     54 Variables created
# 2026-06-20 14:34:55,115 INFO     106 Operators created
# 2026-06-20 14:34:55,117 INFO     Search start: logistics-4-2
# 2026-06-20 14:34:55,117 INFO     Initial h value: 15.000000
# ...

# %%
# %%bash
# pyperplan --heuristic hadd --search astar benchmarks/logistics/domain.pddl benchmarks/logistics/task05.pddl
# Out:
# 2026-06-20 14:35:00,475 INFO     Python version: 3.12.13 (main, Mar  4 2026, 09:23:07) [GCC 11.4.0]
# 2026-06-20 14:35:00,475 INFO     using search: astar_search
# 2026-06-20 14:35:00,475 INFO     using heuristic: hAddHeuristic
# 2026-06-20 14:35:00,475 INFO     Parsing Domain /content/benchmarks/logistics/domain.pddl
# 2026-06-20 14:35:00,476 INFO     Parsing Problem /content/benchmarks/logistics/task05.pddl
# 2026-06-20 14:35:00,477 INFO     3 Predicates parsed
# 2026-06-20 14:35:00,477 INFO     6 Actions parsed
# 2026-06-20 14:35:00,477 INFO     15 Objects parsed
# 2026-06-20 14:35:00,477 INFO     0 Constants parsed
# 2026-06-20 14:35:00,477 INFO     Grounding start: logistics-5-1
# 2026-06-20 14:35:00,481 INFO     Grounding end: logistics-5-1
# 2026-06-20 14:35:00,481 INFO     54 Variables created
# 2026-06-20 14:35:00,481 INFO     130 Operators created
# 2026-06-20 14:35:00,482 INFO     Search start: logistics-5-1
# 2026-06-20 14:35:00,483 INFO     Initial h value: 18.000000
# ...

# %% [markdown]
# Pyperplan com A* e hmax:

# %%
# %%bash
# pyperplan --heuristic hmax --search astar benchmarks/logistics/domain.pddl benchmarks/logistics/task01.pddl
# Out:
# 2026-06-20 14:35:07,417 INFO     Python version: 3.12.13 (main, Mar  4 2026, 09:23:07) [GCC 11.4.0]
# 2026-06-20 14:35:07,417 INFO     using search: astar_search
# 2026-06-20 14:35:07,417 INFO     using heuristic: hMaxHeuristic
# 2026-06-20 14:35:07,417 INFO     Parsing Domain /content/benchmarks/logistics/domain.pddl
# 2026-06-20 14:35:07,419 INFO     Parsing Problem /content/benchmarks/logistics/task01.pddl
# 2026-06-20 14:35:07,420 INFO     3 Predicates parsed
# 2026-06-20 14:35:07,420 INFO     6 Actions parsed
# 2026-06-20 14:35:07,420 INFO     15 Objects parsed
# 2026-06-20 14:35:07,420 INFO     0 Constants parsed
# 2026-06-20 14:35:07,420 INFO     Grounding start: logistics-4-0
# 2026-06-20 14:35:07,425 INFO     Grounding end: logistics-4-0
# 2026-06-20 14:35:07,425 INFO     54 Variables created
# 2026-06-20 14:35:07,425 INFO     106 Operators created
# 2026-06-20 14:35:07,427 INFO     Search start: logistics-4-0
# 2026-06-20 14:35:07,427 INFO     Initial h value: 6.000000
# ...

# %%
# %%bash
# pyperplan --heuristic hmax --search astar benchmarks/logistics/domain.pddl benchmarks/logistics/task03.pddl
# Out:
# 2026-06-20 14:35:17,085 INFO     Python version: 3.12.13 (main, Mar  4 2026, 09:23:07) [GCC 11.4.0]
# 2026-06-20 14:35:17,085 INFO     using search: astar_search
# 2026-06-20 14:35:17,085 INFO     using heuristic: hMaxHeuristic
# 2026-06-20 14:35:17,085 INFO     Parsing Domain /content/benchmarks/logistics/domain.pddl
# 2026-06-20 14:35:17,087 INFO     Parsing Problem /content/benchmarks/logistics/task03.pddl
# 2026-06-20 14:35:17,088 INFO     3 Predicates parsed
# 2026-06-20 14:35:17,088 INFO     6 Actions parsed
# 2026-06-20 14:35:17,088 INFO     15 Objects parsed
# 2026-06-20 14:35:17,088 INFO     0 Constants parsed
# 2026-06-20 14:35:17,088 INFO     Grounding start: logistics-4-2
# 2026-06-20 14:35:17,092 INFO     Grounding end: logistics-4-2
# 2026-06-20 14:35:17,092 INFO     54 Variables created
# 2026-06-20 14:35:17,092 INFO     106 Operators created
# 2026-06-20 14:35:17,094 INFO     Search start: logistics-4-2
# 2026-06-20 14:35:17,095 INFO     Initial h value: 6.000000
# ...

# %%
# %%bash
# pyperplan --heuristic hmax --search astar benchmarks/logistics/domain.pddl benchmarks/logistics/task05.pddl
# Out:
# 2026-06-20 14:35:32,903 INFO     Python version: 3.12.13 (main, Mar  4 2026, 09:23:07) [GCC 11.4.0]
# 2026-06-20 14:35:32,903 INFO     using search: astar_search
# 2026-06-20 14:35:32,903 INFO     using heuristic: hMaxHeuristic
# 2026-06-20 14:35:32,903 INFO     Parsing Domain /content/benchmarks/logistics/domain.pddl
# 2026-06-20 14:35:32,905 INFO     Parsing Problem /content/benchmarks/logistics/task05.pddl
# 2026-06-20 14:35:32,906 INFO     3 Predicates parsed
# 2026-06-20 14:35:32,906 INFO     6 Actions parsed
# 2026-06-20 14:35:32,906 INFO     15 Objects parsed
# 2026-06-20 14:35:32,906 INFO     0 Constants parsed
# 2026-06-20 14:35:32,907 INFO     Grounding start: logistics-5-1
# 2026-06-20 14:35:32,912 INFO     Grounding end: logistics-5-1
# 2026-06-20 14:35:32,912 INFO     54 Variables created
# 2026-06-20 14:35:32,912 INFO     130 Operators created
# 2026-06-20 14:35:32,915 INFO     Search start: logistics-5-1
# 2026-06-20 14:35:32,915 INFO     Initial h value: 6.000000
# ...

# %% [markdown]
# Pyperplan com A* e hff:

# %%
# %%bash
# pyperplan --heuristic hff --search astar benchmarks/logistics/domain.pddl benchmarks/logistics/task01.pddl
# Out:
# 2026-06-20 14:35:46,240 INFO     Python version: 3.12.13 (main, Mar  4 2026, 09:23:07) [GCC 11.4.0]
# 2026-06-20 14:35:46,241 INFO     using search: astar_search
# 2026-06-20 14:35:46,241 INFO     using heuristic: hFFHeuristic
# 2026-06-20 14:35:46,241 INFO     Parsing Domain /content/benchmarks/logistics/domain.pddl
# 2026-06-20 14:35:46,242 INFO     Parsing Problem /content/benchmarks/logistics/task01.pddl
# 2026-06-20 14:35:46,243 INFO     3 Predicates parsed
# 2026-06-20 14:35:46,243 INFO     6 Actions parsed
# 2026-06-20 14:35:46,243 INFO     15 Objects parsed
# 2026-06-20 14:35:46,243 INFO     0 Constants parsed
# 2026-06-20 14:35:46,243 INFO     Grounding start: logistics-4-0
# 2026-06-20 14:35:46,246 INFO     Grounding end: logistics-4-0
# 2026-06-20 14:35:46,246 INFO     54 Variables created
# 2026-06-20 14:35:46,246 INFO     106 Operators created
# 2026-06-20 14:35:46,247 INFO     Search start: logistics-4-0
# 2026-06-20 14:35:46,248 INFO     Initial h value: 19.000000
# ...

# %%
# %%bash
# pyperplan --heuristic hff --search astar benchmarks/logistics/domain.pddl benchmarks/logistics/task03.pddl
# Out:
# 2026-06-20 14:35:48,785 INFO     Python version: 3.12.13 (main, Mar  4 2026, 09:23:07) [GCC 11.4.0]
# 2026-06-20 14:35:48,786 INFO     using search: astar_search
# 2026-06-20 14:35:48,786 INFO     using heuristic: hFFHeuristic
# 2026-06-20 14:35:48,786 INFO     Parsing Domain /content/benchmarks/logistics/domain.pddl
# 2026-06-20 14:35:48,787 INFO     Parsing Problem /content/benchmarks/logistics/task03.pddl
# 2026-06-20 14:35:48,788 INFO     3 Predicates parsed
# 2026-06-20 14:35:48,788 INFO     6 Actions parsed
# 2026-06-20 14:35:48,788 INFO     15 Objects parsed
# 2026-06-20 14:35:48,788 INFO     0 Constants parsed
# 2026-06-20 14:35:48,788 INFO     Grounding start: logistics-4-2
# 2026-06-20 14:35:48,791 INFO     Grounding end: logistics-4-2
# 2026-06-20 14:35:48,791 INFO     54 Variables created
# 2026-06-20 14:35:48,791 INFO     106 Operators created
# 2026-06-20 14:35:48,792 INFO     Search start: logistics-4-2
# 2026-06-20 14:35:48,792 INFO     Initial h value: 13.000000
# ...

# %%
# %%bash
# pyperplan --heuristic hff --search astar benchmarks/logistics/domain.pddl benchmarks/logistics/task05.pddl
# Out:
# 2026-06-20 14:35:51,017 INFO     Python version: 3.12.13 (main, Mar  4 2026, 09:23:07) [GCC 11.4.0]
# 2026-06-20 14:35:51,018 INFO     using search: astar_search
# 2026-06-20 14:35:51,018 INFO     using heuristic: hFFHeuristic
# 2026-06-20 14:35:51,018 INFO     Parsing Domain /content/benchmarks/logistics/domain.pddl
# 2026-06-20 14:35:51,019 INFO     Parsing Problem /content/benchmarks/logistics/task05.pddl
# 2026-06-20 14:35:51,020 INFO     3 Predicates parsed
# 2026-06-20 14:35:51,020 INFO     6 Actions parsed
# 2026-06-20 14:35:51,020 INFO     15 Objects parsed
# 2026-06-20 14:35:51,020 INFO     0 Constants parsed
# 2026-06-20 14:35:51,020 INFO     Grounding start: logistics-5-1
# 2026-06-20 14:35:51,024 INFO     Grounding end: logistics-5-1
# 2026-06-20 14:35:51,024 INFO     54 Variables created
# 2026-06-20 14:35:51,024 INFO     130 Operators created
# 2026-06-20 14:35:51,025 INFO     Search start: logistics-5-1
# 2026-06-20 14:35:51,026 INFO     Initial h value: 15.000000
# ...

# %% [markdown]
# ### Domínio Blocksworld
#
# <font color='red'> Insira os comandos de execução do Pyperplan para o domínio `blocks` nas células a seguir (cada problema em uma célula).

# %% [markdown]
# Pyperplan com A* e hadd:

# %%
# %%bash
# pyperplan --heuristic hadd --search astar benchmarks/blocks/domain.pddl benchmarks/blocks/task10.pddl
# Out:
# 2026-06-20 14:36:06,486 INFO     Python version: 3.12.13 (main, Mar  4 2026, 09:23:07) [GCC 11.4.0]
# 2026-06-20 14:36:06,486 INFO     using search: astar_search
# 2026-06-20 14:36:06,486 INFO     using heuristic: hAddHeuristic
# 2026-06-20 14:36:06,486 INFO     Parsing Domain /content/benchmarks/blocks/domain.pddl
# 2026-06-20 14:36:06,487 INFO     Parsing Problem /content/benchmarks/blocks/task10.pddl
# 2026-06-20 14:36:06,488 INFO     5 Predicates parsed
# 2026-06-20 14:36:06,488 INFO     4 Actions parsed
# 2026-06-20 14:36:06,488 INFO     7 Objects parsed
# 2026-06-20 14:36:06,488 INFO     0 Constants parsed
# 2026-06-20 14:36:06,488 INFO     Grounding start: blocks-7-0
# 2026-06-20 14:36:06,491 INFO     Grounding end: blocks-7-0
# 2026-06-20 14:36:06,491 INFO     71 Variables created
# 2026-06-20 14:36:06,491 INFO     112 Operators created
# 2026-06-20 14:36:06,493 INFO     Search start: blocks-7-0
# 2026-06-20 14:36:06,493 INFO     Initial h value: 51.000000
# ...

# %%
# %%bash
# pyperplan --heuristic hadd --search astar benchmarks/blocks/domain.pddl benchmarks/blocks/task15.pddl
# Out:
# 2026-06-20 14:36:08,912 INFO     Python version: 3.12.13 (main, Mar  4 2026, 09:23:07) [GCC 11.4.0]
# 2026-06-20 14:36:08,912 INFO     using search: astar_search
# 2026-06-20 14:36:08,912 INFO     using heuristic: hAddHeuristic
# 2026-06-20 14:36:08,912 INFO     Parsing Domain /content/benchmarks/blocks/domain.pddl
# 2026-06-20 14:36:08,913 INFO     Parsing Problem /content/benchmarks/blocks/task15.pddl
# 2026-06-20 14:36:08,914 INFO     5 Predicates parsed
# 2026-06-20 14:36:08,914 INFO     4 Actions parsed
# 2026-06-20 14:36:08,914 INFO     8 Objects parsed
# 2026-06-20 14:36:08,914 INFO     0 Constants parsed
# 2026-06-20 14:36:08,914 INFO     Grounding start: blocks-8-2
# 2026-06-20 14:36:08,918 INFO     Grounding end: blocks-8-2
# 2026-06-20 14:36:08,918 INFO     89 Variables created
# 2026-06-20 14:36:08,918 INFO     144 Operators created
# 2026-06-20 14:36:08,919 INFO     Search start: blocks-8-2
# 2026-06-20 14:36:08,920 INFO     Initial h value: 26.000000
# ...

# %%
# %%bash
# pyperplan --heuristic hadd --search astar benchmarks/blocks/domain.pddl benchmarks/blocks/task20.pddl
# Out:
# 2026-06-20 14:36:13,078 INFO     Python version: 3.12.13 (main, Mar  4 2026, 09:23:07) [GCC 11.4.0]
# 2026-06-20 14:36:13,079 INFO     using search: astar_search
# 2026-06-20 14:36:13,079 INFO     using heuristic: hAddHeuristic
# 2026-06-20 14:36:13,079 INFO     Parsing Domain /content/benchmarks/blocks/domain.pddl
# 2026-06-20 14:36:13,081 INFO     Parsing Problem /content/benchmarks/blocks/task20.pddl
# 2026-06-20 14:36:13,081 INFO     5 Predicates parsed
# 2026-06-20 14:36:13,082 INFO     4 Actions parsed
# 2026-06-20 14:36:13,082 INFO     10 Objects parsed
# 2026-06-20 14:36:13,082 INFO     0 Constants parsed
# 2026-06-20 14:36:13,082 INFO     Grounding start: blocks-10-1
# 2026-06-20 14:36:13,090 INFO     Grounding end: blocks-10-1
# 2026-06-20 14:36:13,090 INFO     131 Variables created
# 2026-06-20 14:36:13,090 INFO     220 Operators created
# 2026-06-20 14:36:13,096 INFO     Search start: blocks-10-1
# 2026-06-20 14:36:13,098 INFO     Initial h value: 62.000000
# ...

# %% [markdown]
# Pyperplan com A* e hmax:

# %%
# %%bash
# pyperplan --heuristic hmax --search astar benchmarks/blocks/domain.pddl benchmarks/blocks/task10.pddl
# Out:
# 2026-06-20 14:36:19,854 INFO     Python version: 3.12.13 (main, Mar  4 2026, 09:23:07) [GCC 11.4.0]
# 2026-06-20 14:36:19,854 INFO     using search: astar_search
# 2026-06-20 14:36:19,854 INFO     using heuristic: hMaxHeuristic
# 2026-06-20 14:36:19,855 INFO     Parsing Domain /content/benchmarks/blocks/domain.pddl
# 2026-06-20 14:36:19,856 INFO     Parsing Problem /content/benchmarks/blocks/task10.pddl
# 2026-06-20 14:36:19,857 INFO     5 Predicates parsed
# 2026-06-20 14:36:19,857 INFO     4 Actions parsed
# 2026-06-20 14:36:19,857 INFO     7 Objects parsed
# 2026-06-20 14:36:19,857 INFO     0 Constants parsed
# 2026-06-20 14:36:19,857 INFO     Grounding start: blocks-7-0
# 2026-06-20 14:36:19,861 INFO     Grounding end: blocks-7-0
# 2026-06-20 14:36:19,861 INFO     71 Variables created
# 2026-06-20 14:36:19,861 INFO     112 Operators created
# 2026-06-20 14:36:19,863 INFO     Search start: blocks-7-0
# 2026-06-20 14:36:19,864 INFO     Initial h value: 8.000000
# ...

# %%
# %%bash
# pyperplan --heuristic hmax --search astar benchmarks/blocks/domain.pddl benchmarks/blocks/task15.pddl
# Out:
# 2026-06-20 14:36:29,046 INFO     Python version: 3.12.13 (main, Mar  4 2026, 09:23:07) [GCC 11.4.0]
# 2026-06-20 14:36:29,046 INFO     using search: astar_search
# 2026-06-20 14:36:29,046 INFO     using heuristic: hMaxHeuristic
# 2026-06-20 14:36:29,046 INFO     Parsing Domain /content/benchmarks/blocks/domain.pddl
# 2026-06-20 14:36:29,047 INFO     Parsing Problem /content/benchmarks/blocks/task15.pddl
# 2026-06-20 14:36:29,048 INFO     5 Predicates parsed
# 2026-06-20 14:36:29,048 INFO     4 Actions parsed
# 2026-06-20 14:36:29,048 INFO     8 Objects parsed
# 2026-06-20 14:36:29,048 INFO     0 Constants parsed
# 2026-06-20 14:36:29,048 INFO     Grounding start: blocks-8-2
# 2026-06-20 14:36:29,051 INFO     Grounding end: blocks-8-2
# 2026-06-20 14:36:29,051 INFO     89 Variables created
# 2026-06-20 14:36:29,051 INFO     144 Operators created
# 2026-06-20 14:36:29,053 INFO     Search start: blocks-8-2
# 2026-06-20 14:36:29,054 INFO     Initial h value: 5.000000
# ...

# %%
# %%bash
# pyperplan --heuristic hmax --search astar benchmarks/blocks/domain.pddl benchmarks/blocks/task20.pddl
# Out:
# Process is terminated.

# %% [markdown]
# Pyperplan com A* e hff:

# %%
# %%bash
# pyperplan --heuristic hff --search astar benchmarks/blocks/domain.pddl benchmarks/blocks/task10.pddl
# Out:
# 2026-06-20 17:12:14,044 INFO     Python version: 3.12.13 (main, Mar  4 2026, 09:23:07) [GCC 11.4.0]
# 2026-06-20 17:12:14,044 INFO     using search: astar_search
# 2026-06-20 17:12:14,044 INFO     using heuristic: hFFHeuristic
# 2026-06-20 17:12:14,044 INFO     Parsing Domain /content/benchmarks/blocks/domain.pddl
# 2026-06-20 17:12:14,047 INFO     Parsing Problem /content/benchmarks/blocks/task10.pddl
# 2026-06-20 17:12:14,049 INFO     5 Predicates parsed
# 2026-06-20 17:12:14,049 INFO     4 Actions parsed
# 2026-06-20 17:12:14,049 INFO     7 Objects parsed
# 2026-06-20 17:12:14,049 INFO     0 Constants parsed
# 2026-06-20 17:12:14,049 INFO     Grounding start: blocks-7-0
# 2026-06-20 17:12:14,056 INFO     Grounding end: blocks-7-0
# 2026-06-20 17:12:14,056 INFO     71 Variables created
# 2026-06-20 17:12:14,056 INFO     112 Operators created
# 2026-06-20 17:12:14,059 INFO     Search start: blocks-7-0
# 2026-06-20 17:12:14,060 INFO     Initial h value: 13.000000
# ...

# %%
# %%bash
# pyperplan --heuristic hff --search astar benchmarks/blocks/domain.pddl benchmarks/blocks/task15.pddl
# Out:
# 2026-06-20 17:12:18,766 INFO     Python version: 3.12.13 (main, Mar  4 2026, 09:23:07) [GCC 11.4.0]
# 2026-06-20 17:12:18,766 INFO     using search: astar_search
# 2026-06-20 17:12:18,766 INFO     using heuristic: hFFHeuristic
# 2026-06-20 17:12:18,766 INFO     Parsing Domain /content/benchmarks/blocks/domain.pddl
# 2026-06-20 17:12:18,770 INFO     Parsing Problem /content/benchmarks/blocks/task15.pddl
# 2026-06-20 17:12:18,773 INFO     5 Predicates parsed
# 2026-06-20 17:12:18,774 INFO     4 Actions parsed
# 2026-06-20 17:12:18,774 INFO     8 Objects parsed
# 2026-06-20 17:12:18,774 INFO     0 Constants parsed
# 2026-06-20 17:12:18,775 INFO     Grounding start: blocks-8-2
# 2026-06-20 17:12:18,785 INFO     Grounding end: blocks-8-2
# 2026-06-20 17:12:18,785 INFO     89 Variables created
# 2026-06-20 17:12:18,786 INFO     144 Operators created
# 2026-06-20 17:12:18,792 INFO     Search start: blocks-8-2
# 2026-06-20 17:12:18,793 INFO     Initial h value: 14.000000
# ...

# %%
# %%bash
# pyperplan --heuristic hff --search astar benchmarks/blocks/domain.pddl benchmarks/blocks/task20.pddl

# %% [markdown]
# # Instruções de envio
#
# Você deve submeter no Moodle dois arquivos:
#
# * Uma cópia do arquivo **EP3-Pyperplan.ipynb** com todas as células previamente preenchidas (quando necessário) e executadas (caso você já tenha o Pyperplan instalado, não é necessário executar a primeira célula). Os outputs devem estar visíveis e legíveis.
# * Um arquivo com extensão **.pdf**, de *no máximo 3 páginas*, contendo a(s) tabela(s) com os resultados estatísticos devolvidos pelo Pyperplan e o texto analisando os resultados.
#
# Importante: Não esqueça de colocar seu nome e NUSP nos arquivos que serão entregues.
